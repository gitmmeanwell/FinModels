# %%
import pandas.io.data as web

# %%
import datetime

# %%
start = datetime.datetime(2014, 6, 1)

# %%
end = datetime.datetime(2017, 1, 1)

# %%
gdp=web.DataReader("GDP", "fred", start, end)

# %%
gdp.ix['2014-10-01']
# Out:
# GDP    17703.7
# Name: 2014-10-01 00:00:00, dtype: float64

# %%
inflation = web.DataReader(["CPIAUCSL", "CPILFESL"], "fred", start, end)

# %%
inflation.head(15)
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2014-06-01   237.348   237.984
# 2014-07-01   237.596   238.217
# 2014-08-01   237.409   238.340
# 2014-09-01   237.626   238.686
# 2014-10-01   237.753   239.120
# 2014-11-01   237.067   239.304
# 2014-12-01   236.284   239.445
# 2015-01-01   234.677   239.871
# 2015-02-01   235.186   240.247
# 2015-03-01   235.740   240.793
# 2015-04-01   235.982   241.409

# %%
pce = web.DataReader(["PCE"], "fred", start, end)

# %%
pce.tail(6)
# Out:
#                 PCE
# DATE
# 2014-10-01  12096.4
# 2014-11-01  12142.2
# 2014-12-01  12122.0
# 2015-01-01  12086.3
# 2015-02-01  12107.1
# 2015-03-01  12160.5

# %%
import matplotlib.pyplot as plt

# %%
# %pylab inline
plt.figure(figsize=(14,4))
pce['PCE'].plot()
plt.ylabel('Billions of Dollars')
plt.title('Personal Consumption Expenditures')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pcectpictm= web.DataReader(["PCECTPICTM"], "fred", start, end)

# %%
pcectpictm.tail(5)
# Out:
#             PCECTPICTM
# DATE
# 2015-01-01        0.70
# 2016-01-01        1.80
# 2017-01-01        1.95

# %%
plt.figure(figsize=(16,3))
pcectpictm['PCECTPICTM'].plot()
plt.ylabel('PCE inflation rate')
plt.title('Summary of Economic Projections for the Personal Consumption Expenditures Inflation Rate')

# %%
dcoilbrenteu= web.DataReader(["DCOILBRENTEU"], "fred", start,end)

# %%
dcoilbrenteu.tail(15)
# Out:
#             DCOILBRENTEU
# DATE
# 2015-04-28         62.61
# 2015-04-29         63.97
# 2015-04-30         63.90
# 2015-05-01         64.13
# 2015-05-04         64.62
# 2015-05-05         65.44
# 2015-05-06         66.22
# 2015-05-07         64.93
# 2015-05-08         63.82
# 2015-05-11         62.82
# 2015-05-12         65.09
# 2015-05-13         66.33
# 2015-05-14         65.58
# 2015-05-15         64.69
# 2015-05-18         65.15

# %%
plt.figure(figsize=(16,4))
dcoilbrenteu['DCOILBRENTEU'].plot()
plt.ylabel('Per Barrel')
plt.title('Brent Crude Europe')

# %%
bamlh0a0hym2=web.DataReader(["BAMLH0A0HYM2"], "fred", start,end)

# %%
bamlh0a0hym2.head(5)
# Out:
#             BAMLH0A0HYM2
# DATE
# 2014-06-02          3.61
# 2014-06-03          3.59
# 2014-06-04          3.59
# 2014-06-05          3.59
# 2014-06-06          3.53

# %%
plt.figure(figsize=(16,4))
bamlh0a0hym2['BAMLH0A0HYM2'].plot()
plt.ylabel('Rate')
plt.title('BofA Merrill Lynch US High Yield Master II Option-Adjusted Spread')

# %%
T5YIFR= web.DataReader("T5YIFR", "fred", start,end)

# %%
T5YIFR.tail(15)
# Out:
#             T5YIFR
# DATE
# 2015-05-01    2.16
# 2015-05-04    2.15
# 2015-05-05    2.16
# 2015-05-06    2.13
# 2015-05-07    2.10
# 2015-05-08    2.10
# 2015-05-11    2.12
# 2015-05-12    2.11
# 2015-05-13    2.05
# 2015-05-14    2.09
# 2015-05-15    2.04
# 2015-05-18    2.08
# 2015-05-19    2.08
# 2015-05-20    2.11
# 2015-05-21    2.05

# %%
# %pylab inline
plt.figure(figsize=(16,4))
T5YIFR['T5YIFR'].plot()
plt.ylabel('T5YIFR')
plt.title('5 Year Treasury')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
type(T5YIFR)
# Out:
# pandas.core.frame.DataFrame

# %%
GFDEGDQ188S= web.DataReader("GFDEGDQ188S", "fred", start,end)

# %%
GFDEGDQ188S.head(5)
# Out:
#             GFDEGDQ188S
# DATE
# 2014-07-01    101.27428
# 2014-10-01    102.47261

# %%
sp500= web.DataReader("SP500", "fred", start,end)

# %%
sp500.tail(15)
# Out:
#               SP500
# DATE
# 2015-05-01  2108.29
# 2015-05-04  2114.49
# 2015-05-05  2089.46
# 2015-05-06  2080.15
# 2015-05-07  2088.00
# 2015-05-08  2116.10
# 2015-05-11  2105.33
# 2015-05-12  2099.12
# 2015-05-13  2098.48
# 2015-05-14  2121.10
# 2015-05-15  2122.73
# 2015-05-18  2129.20
# 2015-05-19  2127.83
# 2015-05-20  2125.85
# 2015-05-21  2130.82

# %%
plt.figure(figsize=(16,4))
sp500['SP500'].plot()
plt.ylabel('Index')
plt.title('S&P Index')

# %%
ECOMNSA= web.DataReader("ECOMNSA", "fred", start,end)

# %%
ECOMNSA.head()
# Out:
#             ECOMNSA
# DATE
# 2014-07-01    70351
# 2014-10-01    93530
# 2015-01-01    74914

# %%
UNRATE=web.DataReader("UNRATE", "fred", start,end)

# %%
UNRATE.tail(5)
# Out:
#             UNRATE
# DATE
# 2014-12-01     5.6
# 2015-01-01     5.7
# 2015-02-01     5.5
# 2015-03-01     5.5
# 2015-04-01     5.4

# %%
GASREGCOVW=web.DataReader("GASREGCOVW", "fred", start,end)

# %%
GASREGCOVW.tail(10)
# Out:
#             GASREGCOVW
# DATE
# 2015-03-16       2.339
# 2015-03-23       2.347
# 2015-03-30       2.348
# 2015-04-06       2.315
# 2015-04-13       2.317
# 2015-04-20       2.393
# 2015-04-27       2.451
# 2015-05-04       2.517
# 2015-05-11       2.547
# 2015-05-18       2.604

# %%
plt.figure(figsize=(16,4))
GASREGCOVW['GASREGCOVW'].plot()
plt.ylabel('Price Per Gallon')
plt.title('US Gas Prices')

# %%
HSN1F=web.DataReader("HSN1F", "fred", start,end)

# %%
HSN1F.tail(10)
# Out:
#             HSN1F
# DATE
# 2014-06-01    409
# 2014-07-01    399
# 2014-08-01    448
# 2014-09-01    456
# 2014-10-01    469
# 2014-11-01    448
# 2014-12-01    496
# 2015-01-01    514
# 2015-02-01    543
# 2015-03-01    481

# %%
# %pylab inline
plt.figure(figsize=(16,4))
HSN1F['HSN1F'].plot()
plt.ylabel('Monthly Starts')
plt.title('Monthly Housing Starts US')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
CFNAI=web.DataReader("CFNAI", "fred", start,end)

# %%
CFNAI.tail(6)
# Out:
#             CFNAI
# DATE
# 2014-11-01   0.85
# 2014-12-01   0.05
# 2015-01-01  -0.26
# 2015-02-01  -0.19
# 2015-03-01  -0.36
# 2015-04-01  -0.15

# %%
plt.figure(figsize=(16,4))
CFNAI['CFNAI'].plot()
plt.title("Chicago Fed National Activity Index")

# %%
NCBCEPNW=web.DataReader("NCBCEPNW", "fred", start,end)

# %%
NCBCEPNW.tail(10)
# Out:
#             NCBCEPNW
# DATE
# 2014-07-01    108.23
# 2014-10-01    109.91

# %%
plt.figure(figsize=(18,4))
NCBCEPNW['NCBCEPNW'].plot()
plt.title('Corporate Equities as a Percentage of Net Worth')

# %%
DPCERL1M225NBEA= web.DataReader("DPCERL1M225NBEA", "fred", start,end)

# %%
DPCERL1M225NBEA.tail(10)
# Out:
#             DPCERL1M225NBEA
# DATE
# 2014-06-01              0.3
# 2014-07-01              0.1
# 2014-08-01              0.7
# 2014-09-01              0.2
# 2014-10-01              0.4
# 2014-11-01              0.5
# 2014-12-01              0.1
# 2015-01-01              0.2
# 2015-02-01              0.0
# 2015-03-01              0.3

# %%
plt.figure(figsize=(18,4))
DPCERL1M225NBEA['DPCERL1M225NBEA'].plot()
plt.title(' Real personal consumption expenditures')
plt.ylabel('Percent Change from Preceding Period')
